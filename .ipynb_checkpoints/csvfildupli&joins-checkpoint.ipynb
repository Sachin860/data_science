# %%
import pandas as pd

# %%
file=pd.read_csv(r'C:\Users\keert\OneDrive\Documents\SampleSuperstore.csv')

# %%
file
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
import pandas as pd
import sqlalchemy as sa
connection_string='mssql+pyodbc://KEERTHANA\MSSQLSERVER01/sachin?driver=ODBC+Driver+17+for+SQL+Server'
engine = sa.create_engine(connection_string)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\keert\AppData\Local\Temp\ipykernel_18012\2448875527.py:3: SyntaxWarning: invalid escape sequence '\M'
#   connection_string='mssql+pyodbc://KEERTHANA\MSSQLSERVER01/sachin?driver=ODBC+Driver+17+for+SQL+Server'

# %%
file.to_sql('samplesuperstore',con=connection_string,if_exists='replace',index=False)
# Out:
# 12

# %%
#loop to insert a csv files

# %%
import pandas as pd
import sqlalchemy as sa
connection_string='mssql+pyodbc://KEERTHANA\MSSQLSERVER01/datasci?driver=ODBC+Driver+17+for+SQL+Server'
engine = sa.create_engine(connection_string)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\keert\AppData\Local\Temp\ipykernel_18012\1059630467.py:3: SyntaxWarning: invalid escape sequence '\M'
#   connection_string='mssql+pyodbc://KEERTHANA\MSSQLSERVER01/datasci?driver=ODBC+Driver+17+for+SQL+Server'

# %%
files = ['artist', 'canvas_size', 'image_link', 'museum','museum_hours', 'product_size', 'subject', 'work']
for file in files:
    pat = rf"‪‪C:\Users\keert\OneDrive\famous_paintings\{file}.csv".replace('\u202a','')
    print(pat)
    df = pd.read_csv(pat)
    df.to_sql(file, con=connection_string, if_exists='replace',index=False)
# Out:
# C:\Users\keert\OneDrive\famous_paintings\artist.csv
# C:\Users\keert\OneDrive\famous_paintings\canvas_size.csv
# C:\Users\keert\OneDrive\famous_paintings\image_link.csv
# C:\Users\keert\OneDrive\famous_paintings\museum.csv
# C:\Users\keert\OneDrive\famous_paintings\museum_hours.csv
# C:\Users\keert\OneDrive\famous_paintings\product_size.csv
# C:\Users\keert\OneDrive\famous_paintings\subject.csv
# C:\Users\keert\OneDrive\famous_paintings\work.csv

# %%
import pandas as pd

# %%
file1=r'‪C:\Users\keert\Downloads\employee.csv'.replace( '\u202a','')
employee=pd.read_csv(file1)
employee
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0            100     Steven      King     SKING  515.123.4567  6/17/2003
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569  1/13/2001
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567   1/3/2006
# 4            104      Bruce     Ernst    BERNST  590.423.4568  5/21/2007
# ..           ...        ...       ...       ...           ...        ...
# 102          202        Pat       Fay      PFAY  603.123.6666  8/17/2005
# 103          203      Susan    Mavris   SMAVRIS  515.123.7777   6/7/2002
# 104          204    Hermann      Baer     HBAER  515.123.8888   6/7/2002
# 105          205    Shelley   Higgins  SHIGGINS  515.123.8080   6/7/2002
# 106          206    William     Gietz    WGIETZ  515.123.8181   6/7/2002
#
#          JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# ...

# %%
file3=r'‪C:\Users\keert\Downloads\department.csv'.replace('\u202a','')
department=pd.read_csv(file3)
department
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# ...

# %%
empolyeedepartment=pd.merge(employee,department,on='DEPARTMENT_ID',how='inner')
empolyeedepartment
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0            100     Steven      King     SKING  515.123.4567  6/17/2003
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569  1/13/2001
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567   1/3/2006
# 4            104      Bruce     Ernst    BERNST  590.423.4568  5/21/2007
# ..           ...        ...       ...       ...           ...        ...
# 101          202        Pat       Fay      PFAY  603.123.6666  8/17/2005
# 102          203      Susan    Mavris   SMAVRIS  515.123.7777   6/7/2002
# 103          204    Hermann      Baer     HBAER  515.123.8888   6/7/2002
# 104          205    Shelley   Higgins  SHIGGINS  515.123.8080   6/7/2002
# 105          206    William     Gietz    WGIETZ  515.123.8181   6/7/2002
#
#          JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID_x  DEPARTMENT_ID  \
# ...

# %%
file4=r'‪C:\Users\keert\Downloads\location.csv'.replace('\u202a','')
location=pd.read_csv(file4)
location
# Out:
#     LOCATION_ID                            STREET_ADDRESS POSTAL_CODE  \
# 0          1000                      1297 Via Cola di Rie         989
# 1          1100                   93091 Calle della Testa       10934
# 2          1200                          2017 Shinjuku-ku        1689
# 3          1300                           9450 Kamiya-cho        6823
# 4          1400                       2014 Jabberwocky Rd       26192
# 5          1500                       2011 Interiors Blvd       99236
# 6          1600                            2007 Zagora St       50090
# 7          1700                           2004 Charade Rd       98199
# 8          1800                           147 Spadina Ave     M5V 2L7
# 9          1900                           6092 Boxwood St     YSW 9T2
# 10         2000                       40-5-12 Laogianggen      190518
# 11         2100                        1298 Vileparle (E)      490231
# ...

# %%
emplocation=pd.merge(empolyeedepartment,location,on='LOCATION_ID',how='inner')
emplocation
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0            100     Steven      King     SKING  515.123.4567  6/17/2003
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569  1/13/2001
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567   1/3/2006
# 4            104      Bruce     Ernst    BERNST  590.423.4568  5/21/2007
# ..           ...        ...       ...       ...           ...        ...
# 101          202        Pat       Fay      PFAY  603.123.6666  8/17/2005
# 102          203      Susan    Mavris   SMAVRIS  515.123.7777   6/7/2002
# 103          204    Hermann      Baer     HBAER  515.123.8888   6/7/2002
# 104          205    Shelley   Higgins  SHIGGINS  515.123.8080   6/7/2002
# 105          206    William     Gietz    WGIETZ  515.123.8181   6/7/2002
#
#          JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID_x  DEPARTMENT_ID  \
# ...

# %%
file5=r'‪C:\Users\keert\Downloads\crt.csv'.replace('\u202a','')
crty=pd.read_csv(file5)
crty
# Out:
#    COUNTRY_ID              COUNTRY_NAME  REGION_ID
# 0          AR                 Argentina          2
# 1          AU                 Australia          3
# 2          BE                   Belgium          1
# 3          BR                    Brazil          2
# 4          CA                    Canada          2
# 5          CH               Switzerland          1
# 6          CN                     China          3
# 7          DE                   Germany          1
# 8          DK                   Denmark          1
# 9          EG                     Egypt          4
# 10         FR                    France          1
# 11         IL                    Israel          4
# 12         IN                     India          3
# 13         IT                     Italy          1
# 14         JP                     Japan          3
# 15         KW                    Kuwait          4
# 16         ML                  Malaysia          3
# ...

# %%
empcrty=pd.merge(emplocation,crty,on='COUNTRY_ID',how='inner')
empcrty
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0            100     Steven      King     SKING  515.123.4567  6/17/2003
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569  1/13/2001
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567   1/3/2006
# 4            104      Bruce     Ernst    BERNST  590.423.4568  5/21/2007
# ..           ...        ...       ...       ...           ...        ...
# 101          202        Pat       Fay      PFAY  603.123.6666  8/17/2005
# 102          203      Susan    Mavris   SMAVRIS  515.123.7777   6/7/2002
# 103          204    Hermann      Baer     HBAER  515.123.8888   6/7/2002
# 104          205    Shelley   Higgins  SHIGGINS  515.123.8080   6/7/2002
# 105          206    William     Gietz    WGIETZ  515.123.8181   6/7/2002
#
#          JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID_x  ...   DEPARTMENT_NAME  \
# ...

# %%
school1=[[1,'sachin','chennai'],[2,'arun','bangalore']]
school2=[[1,'A','chennai'],[2,'B','bangalore'],[3,'c','mumbai']]
school3=[[1,'A','chennai'],[2,'B','bangalore'],[3,'c','mumbai'],[4,'d','delhi']]
school1df=pd.DataFrame(school1,columns=['id','name','place'])
school2df=pd.DataFrame(school2,columns=['id','name','place'])
school3df=pd.DataFrame(school3,columns=['id','name','place'])

# %%
print(school1df,school2df,school3df)
# Out:
#    id    name      place
# 0   1  sachin    chennai
# 1   2    arun  bangalore    id name      place
# 0   1    A    chennai
# 1   2    B  bangalore
# 2   3    c     mumbai    id name      place
# 0   1    A    chennai
# 1   2    B  bangalore
# 2   3    c     mumbai
# 3   4    d      delhi

# %%
finaldf=pd.concat([school1df,school2df,school3df],axis=0)

# %%
finaldf
# Out:
#    id    name      place
# 0   1  sachin    chennai
# 1   2    arun  bangalore
# 0   1       A    chennai
# 1   2       B  bangalore
# 2   3       c     mumbai
# 0   1       A    chennai
# 1   2       B  bangalore
# 2   3       c     mumbai
# 3   4       d      delhi

# %%
finaldf=pd.concat([school1df,school2df,school3df],axis=1)

# %%
finaldf
# Out:
#     id    name      place   id name      place  id name      place
# 0  1.0  sachin    chennai  1.0    A    chennai   1    A    chennai
# 1  2.0    arun  bangalore  2.0    B  bangalore   2    B  bangalore
# 2  NaN     NaN        NaN  3.0    c     mumbai   3    c     mumbai
# 3  NaN     NaN        NaN  NaN  NaN        NaN   4    d      delhi
